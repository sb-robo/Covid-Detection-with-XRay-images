# %%
import pandas as pd
import os
import shutil

# %% [markdown]
# ## Create Train-Test dataset for or Model
#
# - This dataset will contain two types of data. They are,
#   - COVID Positive Xray cases
#   - Normal Xray cases

# %%
if not os.path.exists('./Dataset/train'):
    os.mkdir('./Dataset/train')
    print('Directory created')
else:
    print('Already Created')
# Out:
# Directory created

# %%
if not os.path.exists('./Dataset/test'):
    os.mkdir('./Dataset/test')
    print('Directory created')
else:
    print('Already Created')
# Out:
# Directory created

# %% [markdown]
# #### Train Dataset
#
#
# - Create data for `Covid Positive Xray Cases`

# %%
covid_img_metadata = './Covid_XRAY/metadata.csv'
covid_img_path = './Covid_XRAY/images'

df = pd.read_csv(covid_img_metadata)
print(df.shape)
df.head(n=2)
# Out:
# (372, 29)
#    patientid  offset sex   age   finding survival intubated  \
# 0          2     0.0   M  65.0  COVID-19        Y       NaN
# 1          2     3.0   M  65.0  COVID-19        Y       NaN
#
#   intubation_present went_icu in_icu  ...              date  \
# 0                NaN      NaN    NaN  ...  January 22, 2020
# 1                NaN      NaN    NaN  ...  January 25, 2020
#
#                                       location  folder  \
# 0  Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 1  Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
#
#                                             filename                   doi  \
# 0  auntminnie-a-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 1  auntminnie-b-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
#
#                                                  url  license  \
# 0  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 1  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
#
#                                       clinical_notes other_notes Unnamed: 28
# 0  On January 22, 2020, a 65-year-old man with a ...         NaN         NaN
# 1  On January 22, 2020, a 65-year-old man with a ...         NaN         NaN
#
# [2 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['patientid', 'offset', 'sex', 'age', 'finding', 'survival', 'intubated',
#        'intubation_present', 'went_icu', 'in_icu', 'needed_supplemental_O2',
#        'extubated', 'temperature', 'pO2_saturation', 'leukocyte_count',
#        'neutrophil_count', 'lymphocyte_count', 'view', 'modality', 'date',
#        'location', 'folder', 'filename', 'doi', 'url', 'license',
#        'clinical_notes', 'other_notes', 'Unnamed: 28'],
#       dtype='object')

# %%
target_dir = './Dataset/Train/Covid'

if not os.path.exists(target_dir):
    os.mkdir(target_dir)
    print('Directory Created')
else:
    print('Already Present')
# Out:
# Directory Created

# %%
""" Select those covid data, those 
have a frontview of Xray images."""

count = 0
for (i,row) in df.iterrows():
    if row['finding'] == 'COVID-19' and row['view']=='PA':
        img_name = row['filename']
        img_path = os.path.join(covid_img_path,img_name)
        target_path = os.path.join(target_dir,img_name)
        
        if img_name not in os.listdir(target_dir):
            shutil.copy2(img_path,target_dir)
            print(f'Image moving {img_name}')
        count += 1
        
print(f'Total Images : {count}')
# Out:
# Image moving auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# Image moving auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# Image moving auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# Image moving covid-19-pneumonia-58-day-9.jpg
# Image moving covid-19-pneumonia-58-day-10.jpg
# Image moving covid-19-pneumonia-mild.JPG
# Image moving covid-19-pneumonia-67.jpeg
# Image moving covid-19-pneumonia-bilateral.jpg
# Image moving 16663_1_1.jpg
# Image moving 16660_1_1.jpg
# Image moving 16660_2_1.jpg
# Image moving 16660_3_1.jpg
# Image moving 16660_4_1.jpg
# Image moving 16654_1_1.png
# Image moving 16654_2_1.jpg
# Image moving 16654_4_1.jpg
# Image moving 16672_1_1.jpg
# Image moving 16669_1_1.jpeg
# Image moving 16669_3_1.jpeg
# Image moving 16664_1_1.jpg
# Image moving 4-x-day1.jpg
# Image moving yxppt-2020-02-19_00-51-27_287214-day8.jpg
# Image moving ae6c954c0039de4b5edee53865ffee43-e6c8-0.jpg
# Image moving 6b3bdbc31f65230b8cdcc3cef5f8ba8a-40ac-0.jpg
# Image moving 88de9d8c39e946abd495b37cd07d89e5-2ee6-0.jpg
# Image moving 88de9d8c39e946abd495b37cd07d89e5-6531-0.jpg
# Image moving AR-1.jpg
# Image moving AR-2.jpg
# Image moving 2-chest-filmc.jpg
# Image moving paving.jpg
# Image moving 7-fatal-covid19.jpg
# Image moving extubation-1.jpg
# Image moving extubation-4.jpg
# Image moving extubation-8.jpg
# Image moving extubation-13.jpg
# Image moving 16708_1_1.jpg
# Image moving 16708_4_1.jpg
# Image moving 16708_5_1.jpg
# Image moving covid-19-pneumonia-93.png
# Total Images : 141

# %% [markdown]
# - Create data for `Normal Xray Cases`.

# %%
import random

# %%
target_dir_norm = './Dataset/train/Normal'

if not os.path.exists(target_dir_norm):
    os.mkdir(target_dir_norm)
    print('Directory Created')
else:
    print('Already Present')
# Out:
# Directory Created

# %%
normal_xray_path = './Chest_XRAY/train/NORMAL'

img_names = os.listdir(normal_xray_path)

# %%
for i in range(200):
    img_name = img_names[i]
    img_path = os.path.join(normal_xray_path,img_name)
    target_path = os.path.join(target_dir_norm)
        
    if img_name not in os.listdir(target_dir_norm):
        shutil.copy2(img_path,target_dir_norm)
        print(f'Image moving {img_name} : {i}')
        
print(f'Total Images : {count}')
# Out:
# Image moving IM-0115-0001.jpeg : 0
# Image moving IM-0117-0001.jpeg : 1
# Image moving IM-0119-0001.jpeg : 2
# Image moving IM-0122-0001.jpeg : 3
# Image moving IM-0125-0001.jpeg : 4
# Image moving IM-0127-0001.jpeg : 5
# Image moving IM-0128-0001.jpeg : 6
# Image moving IM-0129-0001.jpeg : 7
# Image moving IM-0131-0001.jpeg : 8
# Image moving IM-0133-0001.jpeg : 9
# Image moving IM-0135-0001.jpeg : 10
# Image moving IM-0137-0001.jpeg : 11
# Image moving IM-0140-0001.jpeg : 12
# Image moving IM-0141-0001.jpeg : 13
# Image moving IM-0143-0001.jpeg : 14
# Image moving IM-0145-0001.jpeg : 15
# Image moving IM-0147-0001.jpeg : 16
# Image moving IM-0149-0001.jpeg : 17
# Image moving IM-0335-0001.jpeg : 152
# Image moving IM-0337-0001.jpeg : 153
# Image moving IM-0338-0001.jpeg : 154
# Image moving IM-0339-0001.jpeg : 155
# Image moving IM-0340-0001.jpeg : 156
# Image moving IM-0341-0001.jpeg : 157
# Image moving IM-0343-0001.jpeg : 158
# Image moving IM-0345-0001.jpeg : 159
# Image moving IM-0346-0001.jpeg : 160
# Image moving IM-0347-0001.jpeg : 161
# Image moving IM-0348-0001.jpeg : 162
# Image moving IM-0349-0001.jpeg : 163
# Image moving IM-0350-0001.jpeg : 164
# Image moving IM-0351-0001.jpeg : 165
# Image moving IM-0353-0001.jpeg : 166
# Image moving IM-0354-0001.jpeg : 167
# Image moving IM-0355-0001.jpeg : 168
# Image moving IM-0356-0001.jpeg : 169
# Image moving IM-0357-0001.jpeg : 170
# Image moving IM-0358-0001.jpeg : 171
# Image moving IM-0359-0001.jpeg : 172
# Image moving IM-0361-0001.jpeg : 173
# Image moving IM-0362-0001.jpeg : 174
# Image moving IM-0363-0001.jpeg : 175
# Image moving IM-0364-0001.jpeg : 176
# Image moving IM-0365-0001.jpeg : 177
# Image moving IM-0367-0001.jpeg : 178
# Image moving IM-0368-0001.jpeg : 179
# Image moving IM-0369-0001.jpeg : 180
# Image moving IM-0370-0001.jpeg : 181
# Image moving IM-0371-0001.jpeg : 182
# Image moving IM-0372-0001.jpeg : 183
# Image moving IM-0374-0001.jpeg : 184
# Image moving IM-0375-0001.jpeg : 185
# Image moving IM-0377-0001.jpeg : 186
# Image moving IM-0379-0001.jpeg : 187
# Image moving IM-0381-0001.jpeg : 188
# Image moving IM-0382-0001.jpeg : 189
# Image moving IM-0383-0001.jpeg : 190
# Image moving IM-0384-0001.jpeg : 191
# Image moving IM-0385-0001.jpeg : 192
# Image moving IM-0386-0001.jpeg : 193
# Image moving IM-0387-0001.jpeg : 194
# Image moving IM-0388-0001.jpeg : 195
# Image moving IM-0389-0001.jpeg : 196
# Image moving IM-0391-0001.jpeg : 197
# Image moving IM-0392-0001.jpeg : 198
# Image moving IM-0393-0001.jpeg : 199
# Total Images : 141

# %% [markdown]
# #### Test Dataset

# %%
target_dir = './Dataset/Test/Covid'

if not os.path.exists(target_dir):
    os.mkdir(target_dir)
    print('Directory Created')
else:
    print('Already Present')
# Out:
# Directory Created

# %%
target_dir = './Dataset/Test/Normal'

if not os.path.exists(target_dir):
    os.mkdir(target_dir)
    print('Directory Created')
else:
    print('Already Present')
# Out:
# Directory Created

# %%
train_root = './Dataset/Train'
test_root = './Dataset/Test'

for i in os.listdir(train_root):
    print(i)
    img_names = os.listdir(os.path.join(train_root,i))
    test_size=int(len(img_names)*0.2)
    
    for j in range(test_size):
        img = img_names[-(j+1)]
        img_path = os.path.join(train_root,i,img)
        
        target_path = os.path.join(test_root,i)
        shutil.move(img_path,target_path)
        
    print(test_size)
# Out:
# Covid
# 28
# Normal
# 40
